# %% [markdown]
# ## Introduction

# %% [markdown]
# In this notebook we trained a model to classify a portrait into one of two classes: generated by AI or candid.
# We used the fastai library to train the model and downloaded data from Kaggle.

# %% [markdown]
# ## Problem Definition

# %% [markdown]
# The fast developments in generative AI bring many benefits, but they also come with notable drawbacks—one of which is the ability to create realistic images of people who do not exist. In this project, we trained a classifier to distinguish between candid portraits and AI-generated images. Being able to accurately classify each photo helps us assess the authenticity of images and increases our confidence in their honesty.

# %% [markdown]
# ### Dependencies

# %%
# !pip install datasets bing-image-downloader
# !{sys.executable} -m pip install fastai
# Out:
# Requirement already satisfied: datasets in c:\users\97254\anaconda3\lib\site-packages (4.4.1)
# Requirement already satisfied: bing-image-downloader in c:\users\97254\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: filelock in c:\users\97254\anaconda3\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\97254\anaconda3\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\97254\anaconda3\lib\site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\97254\anaconda3\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in c:\users\97254\anaconda3\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\97254\anaconda3\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\97254\anaconda3\lib\site-packages (from datasets) (0.27.0)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\97254\anaconda3\lib\site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\97254\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\97254\anaconda3\lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in c:\users\97254\anaconda3\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\97254\anaconda3\lib\site-packages (from datasets) (1.1.5)
# Requirement already satisfied: packaging in c:\users\97254\anaconda3\lib\site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\97254\anaconda3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\97254\anaconda3\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.10.5)
# Requirement already satisfied: anyio in c:\users\97254\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (4.2.0)
# Requirement already satisfied: certifi in c:\users\97254\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\97254\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (1.0.2)
# Requirement already satisfied: idna in c:\users\97254\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: sniffio in c:\users\97254\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\97254\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\97254\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\97254\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.0)
# Requirement already satisfied: typer-slim in c:\users\97254\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\97254\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\97254\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\97254\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: colorama in c:\users\97254\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\97254\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\97254\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\97254\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\97254\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\97254\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\97254\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\97254\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\97254\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\97254\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\97254\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\97254\anaconda3\lib\site-packages (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (8.1.7)
# Requirement already satisfied: fastai in c:\users\97254\anaconda3\lib\site-packages (2.8.5)
# Requirement already satisfied: pip in c:\users\97254\anaconda3\lib\site-packages (from fastai) (24.2)
# Requirement already satisfied: packaging in c:\users\97254\anaconda3\lib\site-packages (from fastai) (24.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\97254\anaconda3\lib\site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.9,>=1.8.0 in c:\users\97254\anaconda3\lib\site-packages (from fastai) (1.8.16)
# Requirement already satisfied: fasttransform>=0.0.2 in c:\users\97254\anaconda3\lib\site-packages (from fastai) (0.0.2)
# Requirement already satisfied: torchvision>=0.11 in c:\users\97254\anaconda3\lib\site-packages (from fastai) (0.24.1)
# Requirement already satisfied: matplotlib in c:\users\97254\anaconda3\lib\site-packages (from fastai) (3.9.2)
# Requirement already satisfied: pandas in c:\users\97254\anaconda3\lib\site-packages (from fastai) (2.2.2)
# Requirement already satisfied: requests in c:\users\97254\anaconda3\lib\site-packages (from fastai) (2.32.3)
# Requirement already satisfied: pyyaml in c:\users\97254\anaconda3\lib\site-packages (from fastai) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\97254\anaconda3\lib\site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\97254\anaconda3\lib\site-packages (from fastai) (10.4.0)
# Requirement already satisfied: scikit-learn in c:\users\97254\anaconda3\lib\site-packages (from fastai) (1.5.1)
# Requirement already satisfied: scipy in c:\users\97254\anaconda3\lib\site-packages (from fastai) (1.13.1)
# Requirement already satisfied: spacy<4 in c:\users\97254\anaconda3\lib\site-packages (from fastai) (3.8.11)
# Requirement already satisfied: plum-dispatch in c:\users\97254\anaconda3\lib\site-packages (from fastai) (2.6.0)
# Requirement already satisfied: cloudpickle in c:\users\97254\anaconda3\lib\site-packages (from fastai) (3.0.0)
# Requirement already satisfied: torch<2.10,>=1.10 in c:\users\97254\anaconda3\lib\site-packages (from fastai) (2.9.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (4.66.5)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (1.26.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\97254\anaconda3\lib\site-packages (from spacy<4->fastai) (75.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\97254\anaconda3\lib\site-packages (from requests->fastai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\97254\anaconda3\lib\site-packages (from requests->fastai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\97254\anaconda3\lib\site-packages (from requests->fastai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\97254\anaconda3\lib\site-packages (from requests->fastai) (2025.1.31)
# Requirement already satisfied: filelock in c:\users\97254\anaconda3\lib\site-packages (from torch<2.10,>=1.10->fastai) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\97254\anaconda3\lib\site-packages (from torch<2.10,>=1.10->fastai) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\97254\anaconda3\lib\site-packages (from torch<2.10,>=1.10->fastai) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\97254\anaconda3\lib\site-packages (from torch<2.10,>=1.10->fastai) (3.3)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\97254\anaconda3\lib\site-packages (from torch<2.10,>=1.10->fastai) (2024.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\97254\anaconda3\lib\site-packages (from matplotlib->fastai) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\97254\anaconda3\lib\site-packages (from matplotlib->fastai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\97254\anaconda3\lib\site-packages (from matplotlib->fastai) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\97254\anaconda3\lib\site-packages (from matplotlib->fastai) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\97254\anaconda3\lib\site-packages (from matplotlib->fastai) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\97254\anaconda3\lib\site-packages (from matplotlib->fastai) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\97254\anaconda3\lib\site-packages (from pandas->fastai) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\97254\anaconda3\lib\site-packages (from pandas->fastai) (2023.3)
# Requirement already satisfied: beartype>=0.16.2 in c:\users\97254\anaconda3\lib\site-packages (from plum-dispatch->fastai) (0.22.6)
# Requirement already satisfied: rich>=10.0 in c:\users\97254\anaconda3\lib\site-packages (from plum-dispatch->fastai) (13.7.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\97254\anaconda3\lib\site-packages (from scikit-learn->fastai) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\97254\anaconda3\lib\site-packages (from scikit-learn->fastai) (3.5.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\97254\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\97254\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (2.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\97254\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\97254\anaconda3\lib\site-packages (from rich>=10.0->plum-dispatch->fastai) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\97254\anaconda3\lib\site-packages (from rich>=10.0->plum-dispatch->fastai) (2.15.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\97254\anaconda3\lib\site-packages (from sympy>=1.13.3->torch<2.10,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\97254\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\97254\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai) (0.1.5)
# Requirement already satisfied: colorama in c:\users\97254\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\97254\anaconda3\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy<4->fastai) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\97254\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy<4->fastai) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\97254\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy<4->fastai) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\97254\anaconda3\lib\site-packages (from jinja2->spacy<4->fastai) (2.1.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\97254\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.0->plum-dispatch->fastai) (0.1.0)

# %% [markdown]
# ### Dataset Creation and Preparation

# %%
from fastai.vision.all import *
from pathlib import Path
from PIL import Image

# %%
folders = ['data/real', 'data/ai']

for f in folders:
    folder = Path(f)
    for img_path in folder.glob('*.png'):
        img = Image.open(img_path)
        img.convert('RGB').save(img_path.with_suffix('.jpg'))
        img_path.unlink()

print('done')
# Out:
# done

# %%
path = Path('.')
dls = ImageDataLoaders.from_folder(
    path,
    train='.',       
    valid_pct=0.2,
    seed=42,
    item_tfms=Resize(224)
)

dls.show_batch(max_n=8)

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.946242</td>
#       <td>0.926234</td>
#       <td>0.400000</td>
#       <td>00:26</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.311894</td>
#       <td>0.166136</td>
#       <td>0.025000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.189335</td>
#       <td>0.044684</td>
#       <td>0.000000</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.127625</td>
#       <td>0.041285</td>
#       <td>0.000000</td>
#       <td>00:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(4,4))
interp.plot_top_losses(9, nrows=3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
def show_prediction(idx):
    img, label = dls.valid_ds[idx]
    pred, pred_idx, probs = learn.predict(img)
    
    print(f'True label    : {label}')
    print(f'Predicted     : {pred}')
    print(f'Confidence    : {probs[pred_idx]:.2f}')
    show_image(img)

# %%
preds, targs = learn.get_preds(dl=dls.valid)
pred_labels = preds.argmax(dim=1)
incorrect_indices = (pred_labels != targs).nonzero().flatten()
correct_indices = (pred_labels == targs).nonzero().flatten()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
print('=== Incorrect predictions ===')
for i in incorrect_indices[:3]:
    show_prediction(i.item())
    print('-' * 40)
# Out:
# === Incorrect predictions ===
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# True label    : TensorCategory(1)
# Predicted     : AI photos
# Confidence    : 0.58
# ----------------------------------------

# %%
print('=== Correct predictions ===')
for i in correct_indices[:3]:
    show_prediction(i.item())
    print('-' * 40)
# Out:
# === Correct predictions ===
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# True label    : TensorCategory(1)
# Predicted     : Real photos
# Confidence    : 0.99
# ----------------------------------------
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# True label    : TensorCategory(0)
# Predicted     : AI photos
# Confidence    : 1.00
# ----------------------------------------
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# True label    : TensorCategory(1)
# Predicted     : Real photos
# Confidence    : 0.63
# ----------------------------------------

# %% [markdown]
# ### Training Curve

# %%
train_losses = [l.item() for l in learn.recorder.losses]
valid_losses = [v[0] for v in learn.recorder.values]

plt.plot(train_losses, label='train loss')
plt.plot(range(0, len(train_losses), len(train_losses)//len(valid_losses)), valid_losses, label='valid loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Model Weaknesses

# %% [markdown]
# The model’s few errors occur when real images look overly smooth or digitally processed, making them visually similar to AI-generated faces. In these cases, the model is also highly confident in its wrong predictions, indicating a blurred decision boundary between the two classes. Additionally, the model is sensitive to image quality issues such as lighting, blur, or contrast, which can lead to misclassification.
